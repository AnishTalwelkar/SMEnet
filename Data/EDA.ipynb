# %%
import pandas as pd
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("H_SME.csv")

# %%
df.head()
# Out:
#    H_id                 Sector       City  No of employees required  \
# 0     1          Agri Products     Nagpur                        46
# 1     2  Transport & Logistics  Bangalore                       112
# 2     3                Textile     Nashik                       148
# 3     4           Construction       Pune                       103
# 4     5                Textile     Mumbai                       140
#
#   Date of joining
# 0      31.07.2020
# 1      04.09.2020
# 2      16.09.2020
# 3      28.08.2020
# 4      03.09.2020

# %%
df_sector = df.groupby('Sector')

# %%
df_sector.head()
# Out:
#     H_id                 Sector       City  No of employees required  \
# 0      1          Agri Products     Nagpur                        46
# 1      2  Transport & Logistics  Bangalore                       112
# 2      3                Textile     Nashik                       148
# 3      4           Construction       Pune                       103
# 4      5                Textile     Mumbai                       140
# 5      6           Construction    Kolkata                         8
# 6      7            Electronics     Nashik                       115
# 7      8          Agri Products     Mumbai                        96
# 8      9                Textile  Bangalore                        87
# 9     10           Construction     Nashik                        17
# 10    11             Automobile       Pune                       149
# 11    12             Automobile    Kolkata                        34
# 12    13                Textile  Bangalore                        19
# ...

# %%
df_agri = df_sector.get_group('Agri Products')
df_agri.head()
# Out:
#     H_id         Sector       City  No of employees required Date of joining
# 0      1  Agri Products     Nagpur                        46      31.07.2020
# 7      8  Agri Products     Mumbai                        96      21.06.2020
# 15    16  Agri Products     Nashik                        25      12.09.2020
# 17    18  Agri Products  Bangalore                        30      19.08.2020
# 21    22  Agri Products    Kolkata                        18      24.06.2020

# %%
df_agri_city = df_agri.groupby('City')

# %%
df_agri_city.get_group('Nashik')
# Out:
#      H_id         Sector    City  No of employees required Date of joining
# 15     16  Agri Products  Nashik                        25      12.09.2020
# 86     87  Agri Products  Nashik                        31      03.07.2020
# 104   105  Agri Products  Nashik                        18      09.07.2020
# 116   117  Agri Products  Nashik                        39      09.08.2020
# 129   130  Agri Products  Nashik                        83      16.07.2020
# 138   139  Agri Products  Nashik                        68      19.08.2020
# 158   159  Agri Products  Nashik                        82      29.08.2020
# 179   180  Agri Products  Nashik                        28      19.08.2020
# 217   218  Agri Products  Nashik                       146      27.07.2020
# 220   221  Agri Products  Nashik                        22      10.09.2020
# 255   256  Agri Products  Nashik                        54      18.07.2020
# ...
